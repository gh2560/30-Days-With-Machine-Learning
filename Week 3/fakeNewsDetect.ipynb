# %%
import os
import kaggle
import pandas as pd 
import seaborn as sns
import numpy as np 
from sys import exit
path=kaggle.data_loading('clmentbisaillon/fake-and-real-news-dataset/code')
print(os.listdir(path))
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 import os
# ----> 2 import kaggle
#       3 import pandas as pd
#       4 import seaborn as sns
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\__init__.py:10
#       8 enable_oauth = os.environ.get("KAGGLE_ENABLE_OAUTH") in ("1", "true", "yes")
#       9 api = KaggleApi(enable_oauth=enable_oauth)
# ---> 10 api.authenticate()
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\api\kaggle_api_extended.py:682, in KaggleApi.authenticate(self)
#     678     print("You must authenticate before you can call the Kaggle API.")
#     679     print(
# ...

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# Chỉ định thư mục chứa tệp kaggle.json
os.environ['KAGGLE_CONFIG_DIR'] = r'C:\Users\<Tên người dùng>\.kaggle'  # Thay thế <Tên người dùng> bằng tên thực tế

# Khởi tạo API và xác thực
api = KaggleApi()
api.authenticate()  # Thực hiện xác thực

print("Xác thực thành công!")
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       7 # Khởi tạo API và xác thực
#       8 api = KaggleApi()
# ----> 9 api.authenticate()  # Thực hiện xác thực
#      11 print("Xác thực thành công!")
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\kaggle\api\kaggle_api_extended.py:682, in KaggleApi.authenticate(self)
#     678     print("You must authenticate before you can call the Kaggle API.")
#     679     print(
#     680         "Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication"
#     681     )
# --> 682 exit(1)
#
# NameError: name 'exit' is not defined
